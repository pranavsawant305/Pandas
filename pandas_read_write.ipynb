# %% [markdown]
# # pandas: panel data

# %% [markdown]
# # library for data manipulation and  analysis

# %% [markdown]
# # types of data:
# - numerical/quantitative:
#   - discrete
#   - continous
# - catagorical/qualitative
#   - nominal
#   - ordinal

# %% [markdown]
# # Numerical/Quantitative: This type of data is numerical in nature and can be measured or counted.
# - Discrete: Discrete data is countable and has a finite number of possible values. Examples include the number of students in a class, the number of apples in a basket, etc.
# - Continuous: Continuous data can take any value within a range and is measurable. Examples include height, weight, temperature, etc.
# # Categorical/Qualitative: This type of data is non-numerical and is used to categorize or describe the attribute of a data unit.
# - Nominal: Nominal data is used for naming or labeling variables without any quantitative value. It’s the simplest form of data. Examples include gender (male, female), hair color (black, brown, blonde), etc.
# - Ordinal: Ordinal data combines the characteristics of both nominal and numerical data. It’s categorical but with a clear ordering of the variables. Examples include ratings (good, better, best), education level (high school, bachelor’s, master’s, Ph.D.), etc.
# # Each type of data has its own statistical measures that can be applied. For example, mean, median, and mode are often used for numerical data, while frequency and mode are used for categorical data. Understanding these types of data is crucial in data analysis and statistics.

# %% [markdown]
# # data analysis pipeline
# - Understand the business  problem
# - collect the related data
# - preprocessing of data
# - finding the insights
# - presenting the insights

# %% [markdown]
# # gathering of data:
#
# - from csv,tsv,excel,txt,json etc
# - database: mysql
# - github
# - kaggle
# - from api
# - webscraping

# %% [markdown]
# # from csv

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.csv")

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # pandas supports two types of data structure
#
# - data frame: tabular data : 2d
# - series: 1 d

# %% [markdown]
# # fetch column names

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'message'], dtype='object')

# %% [markdown]
# # fetch index

# %%
list(df.index)
# Out:
# [0, 1, 2]

# %% [markdown]
# # fetch values

# %%
df.values
# Out:
# array([[1, 2, 3, 4, 'hello'],
#        [5, 6, 7, 8, 'world'],
#        [9, 10, 11, 12, 'foo']], dtype=object)

# %% [markdown]
# # customized column names while reading

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.csv",names=["x","y","z","p","l"])

# %%
df
# Out:
#    x   y   z   p        l
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df.columns
# Out:
# Index(['x', 'y', 'z', 'p', 'l'], dtype='object')

# %% [markdown]
# # default column names

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.csv",header=None)
df
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df.columns
# Out:
# Index(['X', 'a', 'b', 'c', 'd', 'message'], dtype='object')

# %% [markdown]
# # fetching the data till specific row number

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.csv",nrows=3)
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.csv",nrows=2)
df
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %% [markdown]
# # read specific columns

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.csv",usecols=["b","d","message"])
df
# Out:
#     b   d message
# 0   2   4   hello
# 1   6   8   world
# 2  10  12     foo

# %% [markdown]
# # df

# %% [markdown]
# # checking the shape

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.csv")
df
df.shape
# Out:
# (3, 5)

# %% [markdown]
# # column fetching

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
s=df["message"]
s
# Out:
# 0    hello
# 1    world
# 2      foo
# Name: message, dtype: object

# %% [markdown]
# # multiple columns

# %%
df1=df[["a","message"]]
df1
# Out:
#    a message
# 0  1   hello
# 1  5   world
# 2  9     foo

# %%
df1=df[["message"]]
df1
# Out:
#   message
# 0   hello
# 1   world
# 2     foo

# %%
type(df[["message"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # from tsv

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\test.tsv",sep="\t")
df
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
df.columns
# Out:
# Index(['test', ' test', 'test.1', 'test.2', 'test.3'], dtype='object')

# %% [markdown]
# # read excel

# %%
df=pd.read_excel("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.xlsx")
df
# Out:
#    Unnamed: 0    a   b   c   d message
# 0           0  1.0   2   3   4   hello
# 1           1  NaN   6   7   8   world
# 2           2  9.0  10  11  12     foo

# %% [markdown]
# # drop
# # index

# %%
df1=df.drop(columns=["Unnamed: 0"])
df1
# Out:
#      a   b   c   d message
# 0  1.0   2   3   4   hello
# 1  NaN   6   7   8   world
# 2  9.0  10  11  12     foo

# %%
# df.drop(columns=["Unnamed: 0"],inplace=True) # for permenent
# df

# %%
df1
# Out:
#      a   b   c   d message
# 0  1.0   2   3   4   hello
# 1  NaN   6   7   8   world
# 2  9.0  10  11  12     foo

# %%
df
# Out:
#    Unnamed: 0    a   b   c   d message
# 0           0  1.0   2   3   4   hello
# 1           1  NaN   6   7   8   world
# 2           2  9.0  10  11  12     foo

# %% [markdown]
# # how to drop multiple columns

# %%
df.drop(columns=["a","c"])
# Out:
#    Unnamed: 0   b   d message
# 0           0   2   4   hello
# 1           1   6   8   world
# 2           2  10  12     foo

# %% [markdown]
# # or

# %% [markdown]
# # making one or more than one column of data as index
# - give the index/position of that column you want to make as index

# %%
df
# Out:
#    Unnamed: 0    a   b   c   d message
# 0           0  1.0   2   3   4   hello
# 1           1  NaN   6   7   8   world
# 2           2  9.0  10  11  12     foo

# %%
df=pd.read_excel("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.xlsx",index_col=[0])
df
# Out:
#      a   b   c   d message
# 0  1.0   2   3   4   hello
# 1  NaN   6   7   8   world
# 2  9.0  10  11  12     foo

# %%
df=pd.read_excel("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.xlsx",index_col=[2])
df
# Out:
#     Unnamed: 0    a   c   d message
# b
# 2            0  1.0   3   4   hello
# 6            1  NaN   7   8   world
# 10           2  9.0  11  12     foo

# %%
df.index
# Out:
# Index([2, 6, 10], dtype='int64', name='b')

# %%
df=pd.read_excel("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.xlsx",index_col=[2,3])
df
# Out:
#        Unnamed: 0    a   d message
# b  c
# 2  3            0  1.0   4   hello
# 6  7            1  NaN   8   world
# 10 11           2  9.0  12     foo

# %%
df.index
# Out:
# MultiIndex([( 2,  3),
#             ( 6,  7),
#             (10, 11)],
#            names=['b', 'c'])

# %% [markdown]
# # read the excel file from specific sheet

# %%
df=pd.read_excel("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex1.xlsx",sheet_name="BB")
df
# Out:
#    X    a   b   c   d message
# 0  0  1.0   2   3   4   hello
# 1  1  NaN   6   7   8   world
# 2  2  9.0  10  11  12     foo

# %% [markdown]
# # read the file data11

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\data11.csv",skiprows=[0,6])
df
# Out:
#    roll_no  names  course
# 0        1    jai      ds
# 1        2  kirti      ds
# 2        3   tanu      da
# 3        4  teena  python
# 4        5  heena      st

# %% [markdown]
# # fetch ex4

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex4.csv",skiprows=[0,2,3])
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# # read the tabular data from  webpage

# %%
import pandas as pd

# %%
df=pd.read_html("https://www.espn.in/soccer/table/_/leagueV.k?3?4H/eng.1")
df
# Out:
# [                       2023-2024
#  0                    1ARSArsenal
#  1            2MNCManchester City
#  2                  3LIVLiverpool
#  3                4AVLAston Villa
#  4          5TOTTottenham Hotspur
#  5          6MANManchester United
#  6           7NEWNewcastle United
#  7            8WHUWest Ham United
#  8                    9CHEChelsea
#  9           10BOUAFC Bournemouth
#  10  11WOLWolverhampton Wanderers
#  11   12BHABrighton & Hove Albion
#  12                   13FULFulham
#  13           14CRYCrystal Palace
#  14                  15EVEEverton
#  15                16BREBrentford
#  16        17NFONottingham Forest
#  17               18LTNLuton Town
#  18                  19BURBurnley
#  19         20SHUSheffield United,
#      GP   W   D   L   F   A  GD   P
#  0   35  25   5   5  85  28  57  80
#  1   34  24   7   3  82  32  50  79
#  2   35  22   9   4  77  36  41  75
#  3   35  20   7   8  73  52  21  67
#  4   33  18   6   9  67  52  15  60
#  5   34  16   6  12  52  51   1  54
#  6   34  16   5  13  74  55  19  53
#  7   35  13  10  12  56  65  -9  49
#  8   33  13   9  11  63  59   4  48
#  9   35  13   9  13  52  60  -8  48
#  10  35  13   7  15  48  55  -7  46
#  11  34  11  11  12  52  57  -5  44
#  12  35  12   7  16  51  55  -4  43
#  13  35  10  10  15  45  57 -12  40
#  14  35  12   8  15  37  48 -11  36
#  15  35   9   8  18  52  60  -8  35
#  16  35   7   9  19  42  62 -20  26
#  17  35   6   7  22  48  77 -29  25
#  18  35   5   9  21  38  70 -32  24
#  19  35   3   7  25  34  97 -63  16]

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 2

# %%
df[0]
# Out:
#                        2023-2024
# 0                    1ARSArsenal
# 1            2MNCManchester City
# 2                  3LIVLiverpool
# 3                4AVLAston Villa
# 4          5TOTTottenham Hotspur
# 5          6MANManchester United
# 6           7NEWNewcastle United
# 7            8WHUWest Ham United
# 8                    9CHEChelsea
# 9           10BOUAFC Bournemouth
# 10  11WOLWolverhampton Wanderers
# 11   12BHABrighton & Hove Albion
# 12                   13FULFulham
# 13           14CRYCrystal Palace
# 14                  15EVEEverton
# 15                16BREBrentford
# 16        17NFONottingham Forest
# 17               18LTNLuton Town
# 18                  19BURBurnley
# 19         20SHUSheffield United

# %%
df[1]
# Out:
#     GP   W   D   L   F   A  GD   P
# 0   35  25   5   5  85  28  57  80
# 1   34  24   7   3  82  32  50  79
# 2   35  22   9   4  77  36  41  75
# 3   35  20   7   8  73  52  21  67
# 4   33  18   6   9  67  52  15  60
# 5   34  16   6  12  52  51   1  54
# 6   34  16   5  13  74  55  19  53
# 7   35  13  10  12  56  65  -9  49
# 8   33  13   9  11  63  59   4  48
# 9   35  13   9  13  52  60  -8  48
# 10  35  13   7  15  48  55  -7  46
# 11  34  11  11  12  52  57  -5  44
# 12  35  12   7  16  51  55  -4  43
# 13  35  10  10  15  45  57 -12  40
# 14  35  12   8  15  37  48 -11  36
# 15  35   9   8  18  52  60  -8  35
# 16  35   7   9  19  42  62 -20  26
# 17  35   6   7  22  48  77 -29  25
# 18  35   5   9  21  38  70 -32  24
# 19  35   3   7  25  34  97 -63  16

# %%
df1=pd.concat([df[0],df[1]],axis=1) # used to concatinate 
df1
# Out:
#                        2023-2024  GP   W   D   L   F   A  GD   P
# 0                    1ARSArsenal  35  25   5   5  85  28  57  80
# 1            2MNCManchester City  34  24   7   3  82  32  50  79
# 2                  3LIVLiverpool  35  22   9   4  77  36  41  75
# 3                4AVLAston Villa  35  20   7   8  73  52  21  67
# 4          5TOTTottenham Hotspur  33  18   6   9  67  52  15  60
# 5          6MANManchester United  34  16   6  12  52  51   1  54
# 6           7NEWNewcastle United  34  16   5  13  74  55  19  53
# 7            8WHUWest Ham United  35  13  10  12  56  65  -9  49
# 8                    9CHEChelsea  33  13   9  11  63  59   4  48
# 9           10BOUAFC Bournemouth  35  13   9  13  52  60  -8  48
# 10  11WOLWolverhampton Wanderers  35  13   7  15  48  55  -7  46
# 11   12BHABrighton & Hove Albion  34  11  11  12  52  57  -5  44
# 12                   13FULFulham  35  12   7  16  51  55  -4  43
# 13           14CRYCrystal Palace  35  10  10  15  45  57 -12  40
# 14                  15EVEEverton  35  12   8  15  37  48 -11  36
# 15                16BREBrentford  35   9   8  18  52  60  -8  35
# 16        17NFONottingham Forest  35   7   9  19  42  62 -20  26
# 17               18LTNLuton Town  35   6   7  22  48  77 -29  25
# 18                  19BURBurnley  35   5   9  21  38  70 -32  24
# 19         20SHUSheffield United  35   3   7  25  34  97 -63  16

# %% [markdown]
# #  read ex6

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex6.csv")
df
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
df.shape
# Out:
# (10000, 5)

# %%
df[0:60]
# Out:
#          one       two     three      four key
# 0   0.467976 -0.038649 -0.295344 -1.824726   L
# 1  -0.358893  1.404453  0.704965 -0.200638   B
# 2  -0.501840  0.659254 -0.421691 -0.057688   G
# 3   0.204886  1.074134  1.388361 -0.982404   R
# 4   0.354628 -0.133116  0.283763 -0.837063   Q
# 5   1.817480  0.742273  0.419395 -2.251035   Q
# 6  -0.776764  0.935518 -0.332872 -1.875641   U
# 7  -0.913135  1.530624 -0.572657  0.477252   K
# 8   0.358480 -0.497572 -0.367016  0.507702   S
# 9  -1.740877 -1.160417 -1.637830  2.172201   G
# 10  0.240564 -0.328249  1.252155  1.072796   8
# 11  0.764018  1.165476 -0.639544  1.495258   R
# 12  0.571035 -0.310537  0.582437 -0.298765   1
# 13  2.317658  0.430710 -1.334216  0.199679   P
# 14  1.547771 -1.119753 -2.277634  0.329586   J
# 15 -1.310608  0.401719 -1.000987  1.156708   E
# 16 -0.088496  0.634712  0.153324  0.415335   B
# 17 -0.018663 -0.247487 -1.446522  0.750938   A
# 18 -0.070127 -1.579097  0.120892  0.671432   F
# 19 -0.194678 -0.492039  2.359605  0.319810   H
# 20 -0.248618  0.868707 -0.492226 -0.717959   W
# 21 -1.091549 -0.867110 -0.647760 -0.832562   C
# 22  0.641404 -0.138822 -0.621963 -0.284839   C
# 23  1.216408  0.992687  0.165162 -0.069619   V
# 24 -0.564474  0.792832  0.747053  0.571675   I
# 25  1.759879 -0.515666 -0.230481  1.362317   S
# 26  0.126266  0.309281  0.382820 -0.239199   L
# 27  1.334360 -0.100152 -0.840731 -0.643967   6
# 28 -0.737620  0.278087 -0.053235 -0.950972   J
# 29 -1.148486 -0.986292 -0.144963  0.124362   Y
# 30  1.630594  0.243886  0.468368  1.258048   F
# 31  1.044890  0.080718  0.857886 -0.298382   J
# 32 -0.262543 -1.615199 -1.087239  0.759029   T
# 33  0.020144  1.107792 -0.559435 -0.481925   M
# 34 -1.203916  1.885343 -0.080470  0.250646   J
# 35  0.366915 -2.430086 -1.053447  0.346279   A
# 36  0.434220 -0.079863 -0.422977 -0.074272   I
# 37  0.040666 -1.810216 -0.189193  1.229266   G
# 38  1.338459  0.338489 -0.213446  2.325923   Q
# 39  0.572981  0.782664  1.307673  1.619957   X
# 40  0.762428 -0.648529  1.936515 -1.159666   J
# 41 -1.252046 -1.538539  1.042281  0.623835   A
# 42 -0.047530 -0.494310 -0.165460  0.472929   J
# 43  0.124548  0.730791 -0.257527 -1.511257   G
# 44  0.801889 -0.462781 -1.734621  0.674768   R
# 45 -0.992307 -1.096830 -2.061794  0.035391   R
# 46 -0.109663  2.577094  0.913563  0.613594   V
# 47 -0.541681  1.510031  0.467945  0.553225   N
# 48 -0.079587 -0.609924  0.353834  1.108030   M
# 49 -0.043752 -0.410666 -0.729599  0.263223   P
# 50 -0.761490  1.104182  1.270609 -0.319284   O
# 51 -0.804975  0.559520  1.052232 -0.645574   F
# 52  0.353941  1.829963  0.398922 -1.522231   O
# 53  1.541636  0.478316 -0.666760  1.367175   X
# 54 -0.987621  0.337534  0.386935  1.996144   Z
# 55 -0.353462 -0.448433 -0.420520  0.606223   N
# 56 -0.275687  0.127910  0.877756  0.141774   6
# 57  0.448882 -0.016410 -0.041434  0.483096   6
# 58 -0.043765 -0.878446  1.525075  0.008223   Q
# 59 -0.064416  0.080921  0.644715  0.393025   T

# %%
df[0:61] # top5 and bottom 5
# Out:
#          one       two     three      four key
# 0   0.467976 -0.038649 -0.295344 -1.824726   L
# 1  -0.358893  1.404453  0.704965 -0.200638   B
# 2  -0.501840  0.659254 -0.421691 -0.057688   G
# 3   0.204886  1.074134  1.388361 -0.982404   R
# 4   0.354628 -0.133116  0.283763 -0.837063   Q
# ..       ...       ...       ...       ...  ..
# 56 -0.275687  0.127910  0.877756  0.141774   6
# 57  0.448882 -0.016410 -0.041434  0.483096   6
# 58 -0.043765 -0.878446  1.525075  0.008223   Q
# 59 -0.064416  0.080921  0.644715  0.393025   T
# 60  0.015018 -1.620301  0.465866  1.637377   X
#
# [61 rows x 5 columns]

# %% [markdown]
# # maximum limit for displaying the rows is 60

# %% [markdown]
# # how to expend the limit of display:

# %% [markdown]
# - pd.set_option("display.max_rows",None)

# %% [markdown]
# # from json: java script object notation

# %%
import json

# %%
data=json.load(open("C:\PRANAV\Madrid Software\Python\data sets\examples\iris.json"))
data
# Out:
# [{'sepalLength': 5.1,
#   'sepalWidth': 3.5,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.9,
#   'sepalWidth': 3.0,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.7,
#   'sepalWidth': 3.2,
#   'petalLength': 1.3,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.6,
#   'sepalWidth': 3.1,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.6,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.4,
#   'sepalWidth': 3.9,
#   'petalLength': 1.7,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 4.6,
#   'sepalWidth': 3.4,
#   'petalLength': 1.4,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.4,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.4,
#   'sepalWidth': 2.9,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.9,
#   'sepalWidth': 3.1,
#   'petalLength': 1.5,
#   'petalWidth': 0.1,
#   'species': 'setosa'},
#  {'sepalLength': 5.4,
#   'sepalWidth': 3.7,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.8,
#   'sepalWidth': 3.4,
#   'petalLength': 1.6,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.8,
#   'sepalWidth': 3.0,
#   'petalLength': 1.4,
#   'petalWidth': 0.1,
#   'species': 'setosa'},
#  {'sepalLength': 4.3,
#   'sepalWidth': 3.0,
#   'petalLength': 1.1,
#   'petalWidth': 0.1,
#   'species': 'setosa'},
#  {'sepalLength': 5.8,
#   'sepalWidth': 4.0,
#   'petalLength': 1.2,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.7,
#   'sepalWidth': 4.4,
#   'petalLength': 1.5,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 5.4,
#   'sepalWidth': 3.9,
#   'petalLength': 1.3,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 5.1,
#   'sepalWidth': 3.5,
#   'petalLength': 1.4,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 5.7,
#   'sepalWidth': 3.8,
#   'petalLength': 1.7,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 5.1,
#   'sepalWidth': 3.8,
#   'petalLength': 1.5,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 5.4,
#   'sepalWidth': 3.4,
#   'petalLength': 1.7,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.1,
#   'sepalWidth': 3.7,
#   'petalLength': 1.5,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 4.6,
#   'sepalWidth': 3.6,
#   'petalLength': 1.0,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.1,
#   'sepalWidth': 3.3,
#   'petalLength': 1.7,
#   'petalWidth': 0.5,
#   'species': 'setosa'},
#  {'sepalLength': 4.8,
#   'sepalWidth': 3.4,
#   'petalLength': 1.9,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.0,
#   'petalLength': 1.6,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.4,
#   'petalLength': 1.6,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 5.2,
#   'sepalWidth': 3.5,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.2,
#   'sepalWidth': 3.4,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.7,
#   'sepalWidth': 3.2,
#   'petalLength': 1.6,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.8,
#   'sepalWidth': 3.1,
#   'petalLength': 1.6,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.4,
#   'sepalWidth': 3.4,
#   'petalLength': 1.5,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 5.2,
#   'sepalWidth': 4.1,
#   'petalLength': 1.5,
#   'petalWidth': 0.1,
#   'species': 'setosa'},
#  {'sepalLength': 5.5,
#   'sepalWidth': 4.2,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.9,
#   'sepalWidth': 3.1,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.2,
#   'petalLength': 1.2,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.5,
#   'sepalWidth': 3.5,
#   'petalLength': 1.3,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.9,
#   'sepalWidth': 3.6,
#   'petalLength': 1.4,
#   'petalWidth': 0.1,
#   'species': 'setosa'},
#  {'sepalLength': 4.4,
#   'sepalWidth': 3.0,
#   'petalLength': 1.3,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.1,
#   'sepalWidth': 3.4,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.5,
#   'petalLength': 1.3,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 4.5,
#   'sepalWidth': 2.3,
#   'petalLength': 1.3,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 4.4,
#   'sepalWidth': 3.2,
#   'petalLength': 1.3,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.5,
#   'petalLength': 1.6,
#   'petalWidth': 0.6,
#   'species': 'setosa'},
#  {'sepalLength': 5.1,
#   'sepalWidth': 3.8,
#   'petalLength': 1.9,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 4.8,
#   'sepalWidth': 3.0,
#   'petalLength': 1.4,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 5.1,
#   'sepalWidth': 3.8,
#   'petalLength': 1.6,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.6,
#   'sepalWidth': 3.2,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.3,
#   'sepalWidth': 3.7,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.3,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 7.0,
#   'sepalWidth': 3.2,
#   'petalLength': 4.7,
#   'petalWidth': 1.4,
#   'species': 'versicolor'},
#  {'sepalLength': 6.4,
#   'sepalWidth': 3.2,
#   'petalLength': 4.5,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 6.9,
#   'sepalWidth': 3.1,
#   'petalLength': 4.9,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 5.5,
#   'sepalWidth': 2.3,
#   'petalLength': 4.0,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 6.5,
#   'sepalWidth': 2.8,
#   'petalLength': 4.6,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 5.7,
#   'sepalWidth': 2.8,
#   'petalLength': 4.5,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 3.3,
#   'petalLength': 4.7,
#   'petalWidth': 1.6,
#   'species': 'versicolor'},
#  {'sepalLength': 4.9,
#   'sepalWidth': 2.4,
#   'petalLength': 3.3,
#   'petalWidth': 1.0,
#   'species': 'versicolor'},
#  {'sepalLength': 6.6,
#   'sepalWidth': 2.9,
#   'petalLength': 4.6,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 5.2,
#   'sepalWidth': 2.7,
#   'petalLength': 3.9,
#   'petalWidth': 1.4,
#   'species': 'versicolor'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 2.0,
#   'petalLength': 3.5,
#   'petalWidth': 1.0,
#   'species': 'versicolor'},
#  {'sepalLength': 5.9,
#   'sepalWidth': 3.0,
#   'petalLength': 4.2,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 6.0,
#   'sepalWidth': 2.2,
#   'petalLength': 4.0,
#   'petalWidth': 1.0,
#   'species': 'versicolor'},
#  {'sepalLength': 6.1,
#   'sepalWidth': 2.9,
#   'petalLength': 4.7,
#   'petalWidth': 1.4,
#   'species': 'versicolor'},
#  {'sepalLength': 5.6,
#   'sepalWidth': 2.9,
#   'petalLength': 3.6,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 6.7,
#   'sepalWidth': 3.1,
#   'petalLength': 4.4,
#   'petalWidth': 1.4,
#   'species': 'versicolor'},
#  {'sepalLength': 5.6,
#   'sepalWidth': 3.0,
#   'petalLength': 4.5,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 5.8,
#   'sepalWidth': 2.7,
#   'petalLength': 4.1,
#   'petalWidth': 1.0,
#   'species': 'versicolor'},
#  {'sepalLength': 6.2,
#   'sepalWidth': 2.2,
#   'petalLength': 4.5,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 5.6,
#   'sepalWidth': 2.5,
#   'petalLength': 3.9,
#   'petalWidth': 1.1,
#   'species': 'versicolor'},
#  {'sepalLength': 5.9,
#   'sepalWidth': 3.2,
#   'petalLength': 4.8,
#   'petalWidth': 1.8,
#   'species': 'versicolor'},
#  {'sepalLength': 6.1,
#   'sepalWidth': 2.8,
#   'petalLength': 4.0,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 2.5,
#   'petalLength': 4.9,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 6.1,
#   'sepalWidth': 2.8,
#   'petalLength': 4.7,
#   'petalWidth': 1.2,
#   'species': 'versicolor'},
#  {'sepalLength': 6.4,
#   'sepalWidth': 2.9,
#   'petalLength': 4.3,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 6.6,
#   'sepalWidth': 3.0,
#   'petalLength': 4.4,
#   'petalWidth': 1.4,
#   'species': 'versicolor'},
#  {'sepalLength': 6.8,
#   'sepalWidth': 2.8,
#   'petalLength': 4.8,
#   'petalWidth': 1.4,
#   'species': 'versicolor'},
#  {'sepalLength': 6.7,
#   'sepalWidth': 3.0,
#   'petalLength': 5.0,
#   'petalWidth': 1.7,
#   'species': 'versicolor'},
#  {'sepalLength': 6.0,
#   'sepalWidth': 2.9,
#   'petalLength': 4.5,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 5.7,
#   'sepalWidth': 2.6,
#   'petalLength': 3.5,
#   'petalWidth': 1.0,
#   'species': 'versicolor'},
#  {'sepalLength': 5.5,
#   'sepalWidth': 2.4,
#   'petalLength': 3.8,
#   'petalWidth': 1.1,
#   'species': 'versicolor'},
#  {'sepalLength': 5.5,
#   'sepalWidth': 2.4,
#   'petalLength': 3.7,
#   'petalWidth': 1.0,
#   'species': 'versicolor'},
#  {'sepalLength': 5.8,
#   'sepalWidth': 2.7,
#   'petalLength': 3.9,
#   'petalWidth': 1.2,
#   'species': 'versicolor'},
#  {'sepalLength': 6.0,
#   'sepalWidth': 2.7,
#   'petalLength': 5.1,
#   'petalWidth': 1.6,
#   'species': 'versicolor'},
#  {'sepalLength': 5.4,
#   'sepalWidth': 3.0,
#   'petalLength': 4.5,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 6.0,
#   'sepalWidth': 3.4,
#   'petalLength': 4.5,
#   'petalWidth': 1.6,
#   'species': 'versicolor'},
#  {'sepalLength': 6.7,
#   'sepalWidth': 3.1,
#   'petalLength': 4.7,
#   'petalWidth': 1.5,
#   'species': 'versicolor'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 2.3,
#   'petalLength': 4.4,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 5.6,
#   'sepalWidth': 3.0,
#   'petalLength': 4.1,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 5.5,
#   'sepalWidth': 2.5,
#   'petalLength': 4.0,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 5.5,
#   'sepalWidth': 2.6,
#   'petalLength': 4.4,
#   'petalWidth': 1.2,
#   'species': 'versicolor'},
#  {'sepalLength': 6.1,
#   'sepalWidth': 3.0,
#   'petalLength': 4.6,
#   'petalWidth': 1.4,
#   'species': 'versicolor'},
#  {'sepalLength': 5.8,
#   'sepalWidth': 2.6,
#   'petalLength': 4.0,
#   'petalWidth': 1.2,
#   'species': 'versicolor'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 2.3,
#   'petalLength': 3.3,
#   'petalWidth': 1.0,
#   'species': 'versicolor'},
#  {'sepalLength': 5.6,
#   'sepalWidth': 2.7,
#   'petalLength': 4.2,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 5.7,
#   'sepalWidth': 3.0,
#   'petalLength': 4.2,
#   'petalWidth': 1.2,
#   'species': 'versicolor'},
#  {'sepalLength': 5.7,
#   'sepalWidth': 2.9,
#   'petalLength': 4.2,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 6.2,
#   'sepalWidth': 2.9,
#   'petalLength': 4.3,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 5.1,
#   'sepalWidth': 2.5,
#   'petalLength': 3.0,
#   'petalWidth': 1.1,
#   'species': 'versicolor'},
#  {'sepalLength': 5.7,
#   'sepalWidth': 2.8,
#   'petalLength': 4.1,
#   'petalWidth': 1.3,
#   'species': 'versicolor'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 3.3,
#   'petalLength': 6.0,
#   'petalWidth': 2.5,
#   'species': 'virginica'},
#  {'sepalLength': 5.8,
#   'sepalWidth': 2.7,
#   'petalLength': 5.1,
#   'petalWidth': 1.9,
#   'species': 'virginica'},
#  {'sepalLength': 7.1,
#   'sepalWidth': 3.0,
#   'petalLength': 5.9,
#   'petalWidth': 2.1,
#   'species': 'virginica'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 2.9,
#   'petalLength': 5.6,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 6.5,
#   'sepalWidth': 3.0,
#   'petalLength': 5.8,
#   'petalWidth': 2.2,
#   'species': 'virginica'},
#  {'sepalLength': 7.6,
#   'sepalWidth': 3.0,
#   'petalLength': 6.6,
#   'petalWidth': 2.1,
#   'species': 'virginica'},
#  {'sepalLength': 4.9,
#   'sepalWidth': 2.5,
#   'petalLength': 4.5,
#   'petalWidth': 1.7,
#   'species': 'virginica'},
#  {'sepalLength': 7.3,
#   'sepalWidth': 2.9,
#   'petalLength': 6.3,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 6.7,
#   'sepalWidth': 2.5,
#   'petalLength': 5.8,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 7.2,
#   'sepalWidth': 3.6,
#   'petalLength': 6.1,
#   'petalWidth': 2.5,
#   'species': 'virginica'},
#  {'sepalLength': 6.5,
#   'sepalWidth': 3.2,
#   'petalLength': 5.1,
#   'petalWidth': 2.0,
#   'species': 'virginica'},
#  {'sepalLength': 6.4,
#   'sepalWidth': 2.7,
#   'petalLength': 5.3,
#   'petalWidth': 1.9,
#   'species': 'virginica'},
#  {'sepalLength': 6.8,
#   'sepalWidth': 3.0,
#   'petalLength': 5.5,
#   'petalWidth': 2.1,
#   'species': 'virginica'},
#  {'sepalLength': 5.7,
#   'sepalWidth': 2.5,
#   'petalLength': 5.0,
#   'petalWidth': 2.0,
#   'species': 'virginica'},
#  {'sepalLength': 5.8,
#   'sepalWidth': 2.8,
#   'petalLength': 5.1,
#   'petalWidth': 2.4,
#   'species': 'virginica'},
#  {'sepalLength': 6.4,
#   'sepalWidth': 3.2,
#   'petalLength': 5.3,
#   'petalWidth': 2.3,
#   'species': 'virginica'},
#  {'sepalLength': 6.5,
#   'sepalWidth': 3.0,
#   'petalLength': 5.5,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 7.7,
#   'sepalWidth': 3.8,
#   'petalLength': 6.7,
#   'petalWidth': 2.2,
#   'species': 'virginica'},
#  {'sepalLength': 7.7,
#   'sepalWidth': 2.6,
#   'petalLength': 6.9,
#   'petalWidth': 2.3,
#   'species': 'virginica'},
#  {'sepalLength': 6.0,
#   'sepalWidth': 2.2,
#   'petalLength': 5.0,
#   'petalWidth': 1.5,
#   'species': 'virginica'},
#  {'sepalLength': 6.9,
#   'sepalWidth': 3.2,
#   'petalLength': 5.7,
#   'petalWidth': 2.3,
#   'species': 'virginica'},
#  {'sepalLength': 5.6,
#   'sepalWidth': 2.8,
#   'petalLength': 4.9,
#   'petalWidth': 2.0,
#   'species': 'virginica'},
#  {'sepalLength': 7.7,
#   'sepalWidth': 2.8,
#   'petalLength': 6.7,
#   'petalWidth': 2.0,
#   'species': 'virginica'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 2.7,
#   'petalLength': 4.9,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 6.7,
#   'sepalWidth': 3.3,
#   'petalLength': 5.7,
#   'petalWidth': 2.1,
#   'species': 'virginica'},
#  {'sepalLength': 7.2,
#   'sepalWidth': 3.2,
#   'petalLength': 6.0,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 6.2,
#   'sepalWidth': 2.8,
#   'petalLength': 4.8,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 6.1,
#   'sepalWidth': 3.0,
#   'petalLength': 4.9,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 6.4,
#   'sepalWidth': 2.8,
#   'petalLength': 5.6,
#   'petalWidth': 2.1,
#   'species': 'virginica'},
#  {'sepalLength': 7.2,
#   'sepalWidth': 3.0,
#   'petalLength': 5.8,
#   'petalWidth': 1.6,
#   'species': 'virginica'},
#  {'sepalLength': 7.4,
#   'sepalWidth': 2.8,
#   'petalLength': 6.1,
#   'petalWidth': 1.9,
#   'species': 'virginica'},
#  {'sepalLength': 7.9,
#   'sepalWidth': 3.8,
#   'petalLength': 6.4,
#   'petalWidth': 2.0,
#   'species': 'virginica'},
#  {'sepalLength': 6.4,
#   'sepalWidth': 2.8,
#   'petalLength': 5.6,
#   'petalWidth': 2.2,
#   'species': 'virginica'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 2.8,
#   'petalLength': 5.1,
#   'petalWidth': 1.5,
#   'species': 'virginica'},
#  {'sepalLength': 6.1,
#   'sepalWidth': 2.6,
#   'petalLength': 5.6,
#   'petalWidth': 1.4,
#   'species': 'virginica'},
#  {'sepalLength': 7.7,
#   'sepalWidth': 3.0,
#   'petalLength': 6.1,
#   'petalWidth': 2.3,
#   'species': 'virginica'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 3.4,
#   'petalLength': 5.6,
#   'petalWidth': 2.4,
#   'species': 'virginica'},
#  {'sepalLength': 6.4,
#   'sepalWidth': 3.1,
#   'petalLength': 5.5,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 6.0,
#   'sepalWidth': 3.0,
#   'petalLength': 4.8,
#   'petalWidth': 1.8,
#   'species': 'virginica'},
#  {'sepalLength': 6.9,
#   'sepalWidth': 3.1,
#   'petalLength': 5.4,
#   'petalWidth': 2.1,
#   'species': 'virginica'},
#  {'sepalLength': 6.7,
#   'sepalWidth': 3.1,
#   'petalLength': 5.6,
#   'petalWidth': 2.4,
#   'species': 'virginica'},
#  {'sepalLength': 6.9,
#   'sepalWidth': 3.1,
#   'petalLength': 5.1,
#   'petalWidth': 2.3,
#   'species': 'virginica'},
#  {'sepalLength': 5.8,
#   'sepalWidth': 2.7,
#   'petalLength': 5.1,
#   'petalWidth': 1.9,
#   'species': 'virginica'},
#  {'sepalLength': 6.8,
#   'sepalWidth': 3.2,
#   'petalLength': 5.9,
#   'petalWidth': 2.3,
#   'species': 'virginica'},
#  {'sepalLength': 6.7,
#   'sepalWidth': 3.3,
#   'petalLength': 5.7,
#   'petalWidth': 2.5,
#   'species': 'virginica'},
#  {'sepalLength': 6.7,
#   'sepalWidth': 3.0,
#   'petalLength': 5.2,
#   'petalWidth': 2.3,
#   'species': 'virginica'},
#  {'sepalLength': 6.3,
#   'sepalWidth': 2.5,
#   'petalLength': 5.0,
#   'petalWidth': 1.9,
#   'species': 'virginica'},
#  {'sepalLength': 6.5,
#   'sepalWidth': 3.0,
#   'petalLength': 5.2,
#   'petalWidth': 2.0,
#   'species': 'virginica'},
#  {'sepalLength': 6.2,
#   'sepalWidth': 3.4,
#   'petalLength': 5.4,
#   'petalWidth': 2.3,
#   'species': 'virginica'},
#  {'sepalLength': 5.9,
#   'sepalWidth': 3.0,
#   'petalLength': 5.1,
#   'petalWidth': 1.8,
#   'species': 'virginica'}]

# %%
df1=pd.read_json("C:\PRANAV\Madrid Software\Python\data sets\examples\iris.json")
df1
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
data=json.load(open("C:\PRANAV\Madrid Software\Python\data sets\examples\covid.json"))
data
# Out:
# {'AFG': {'continent': 'Asia',
#   'location': 'Afghanistan',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 156392.0,
#   'new_cases': 29.0,
#   'new_cases_smoothed': 28.0,
#   'total_deaths': 7284.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 2.143,
#   'total_cases_per_million': 3925.953,
#   'new_cases_per_million': 0.728,
#   'new_cases_smoothed_per_million': 0.703,
#   'total_deaths_per_million': 182.852,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 0.054,
#   'reproduction_rate': 0.91,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 3398410.0,
#   'people_vaccinated': 3398410.0,
#   'people_fully_vaccinated': 2544223.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 70357.0,
#   'total_vaccinations_per_hundred': 8.53,
#   'people_vaccinated_per_hundred': 8.53,
#   'people_fully_vaccinated_per_hundred': 6.39,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 1766.0,
#   'stringency_index': 27.78,
#   'population': 39835428.0,
#   'population_density': 54.422,
#   'median_age': 18.6,
#   'aged_65_older': 2.581,
#   'aged_70_older': 1.337,
#   'gdp_per_capita': 1803.987,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 597.029,
#   'diabetes_prevalence': 9.59,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': 37.746,
#   'hospital_beds_per_thousand': 0.5,
#   'life_expectancy': 64.83,
#   'human_development_index': 0.511,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'OWID_AFR': {'continent': None,
#   'location': 'Africa',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 8526645.0,
#   'new_cases': 9597.0,
#   'new_cases_smoothed': 4754.429,
#   'total_deaths': 219201.0,
#   'new_deaths': 236.0,
#   'new_deaths_smoothed': 173.429,
#   'total_cases_per_million': 6208.03,
#   'new_cases_per_million': 6.987,
#   'new_cases_smoothed_per_million': 3.462,
#   'total_deaths_per_million': 159.595,
#   'new_deaths_per_million': 0.172,
#   'new_deaths_smoothed_per_million': 0.126,
#   'reproduction_rate': None,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 202114737.0,
#   'people_vaccinated': 126093437.0,
#   'people_fully_vaccinated': 84712120.0,
#   'total_boosters': 163744.0,
#   'new_vaccinations': 24645.0,
#   'new_vaccinations_smoothed': 1238349.0,
#   'total_vaccinations_per_hundred': 14.72,
#   'people_vaccinated_per_hundred': 9.18,
#   'people_fully_vaccinated_per_hundred': 6.17,
#   'total_boosters_per_hundred': 0.01,
#   'new_vaccinations_smoothed_per_million': 902.0,
#   'stringency_index': None,
#   'population': 1373486472.0,
#   'population_density': None,
#   'median_age': None,
#   'aged_65_older': None,
#   'aged_70_older': None,
#   'gdp_per_capita': None,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': None,
#   'diabetes_prevalence': None,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': None,
#   'life_expectancy': None,
#   'human_development_index': None,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'ALB': {'continent': 'Europe',
#   'location': 'Albania',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 187994.0,
#   'new_cases': 631.0,
#   'new_cases_smoothed': 522.0,
#   'total_deaths': 2948.0,
#   'new_deaths': 4.0,
#   'new_deaths_smoothed': 5.571,
#   'total_cases_per_million': 65436.24,
#   'new_cases_per_million': 219.636,
#   'new_cases_smoothed_per_million': 181.696,
#   'total_deaths_per_million': 1026.129,
#   'new_deaths_per_million': 1.392,
#   'new_deaths_smoothed_per_million': 1.939,
#   'reproduction_rate': 1.01,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 1926604.0,
#   'people_vaccinated': 1025180.0,
#   'people_fully_vaccinated': 898625.0,
#   'total_boosters': 2799.0,
#   'new_vaccinations': 5172.0,
#   'new_vaccinations_smoothed': 5080.0,
#   'total_vaccinations_per_hundred': 67.06,
#   'people_vaccinated_per_hundred': 35.68,
#   'people_fully_vaccinated_per_hundred': 31.28,
#   'total_boosters_per_hundred': 0.1,
#   'new_vaccinations_smoothed_per_million': 1768.0,
#   'stringency_index': None,
#   'population': 2872934.0,
#   'population_density': 104.871,
#   'median_age': 38.0,
#   'aged_65_older': 13.188,
#   'aged_70_older': 8.643,
#   'gdp_per_capita': 11803.431,
#   'extreme_poverty': 1.1,
#   'cardiovasc_death_rate': 304.195,
#   'diabetes_prevalence': 10.08,
#   'female_smokers': 7.1,
#   'male_smokers': 51.2,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 2.89,
#   'life_expectancy': 78.57,
#   'human_development_index': 0.795,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'DZA': {'continent': 'Africa',
#   'location': 'Algeria',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 206995.0,
#   'new_cases': 117.0,
#   'new_cases_smoothed': 103.571,
#   'total_deaths': 5939.0,
#   'new_deaths': 3.0,
#   'new_deaths_smoothed': 3.714,
#   'total_cases_per_million': 4639.414,
#   'new_cases_per_million': 2.622,
#   'new_cases_smoothed_per_million': 2.321,
#   'total_deaths_per_million': 133.112,
#   'new_deaths_per_million': 0.067,
#   'new_deaths_smoothed_per_million': 0.083,
#   'reproduction_rate': 1.08,
#   'icu_patients': 16.0,
#   'icu_patients_per_million': 0.359,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 11224643.0,
#   'people_vaccinated': 6381144.0,
#   'people_fully_vaccinated': 4843499.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 14083.0,
#   'total_vaccinations_per_hundred': 25.16,
#   'people_vaccinated_per_hundred': 14.3,
#   'people_fully_vaccinated_per_hundred': 10.86,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 316.0,
#   'stringency_index': 39.81,
#   'population': 44616626.0,
#   'population_density': 17.348,
#   'median_age': 29.1,
#   'aged_65_older': 6.211,
#   'aged_70_older': 3.857,
#   'gdp_per_capita': 13913.839,
#   'extreme_poverty': 0.5,
#   'cardiovasc_death_rate': 278.364,
#   'diabetes_prevalence': 6.73,
#   'female_smokers': 0.7,
#   'male_smokers': 30.4,
#   'handwashing_facilities': 83.741,
#   'hospital_beds_per_thousand': 1.9,
#   'life_expectancy': 76.88,
#   'human_development_index': 0.748,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'AND': {'continent': 'Europe',
#   'location': 'Andorra',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 15618.0,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 14.571,
#   'total_deaths': 130.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 0.0,
#   'total_cases_per_million': 201902.94,
#   'new_cases_per_million': 0.0,
#   'new_cases_smoothed_per_million': 188.373,
#   'total_deaths_per_million': 1680.585,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 0.0,
#   'reproduction_rate': 1.45,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': 222097.0,
#   'total_tests_per_thousand': 2871.177,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': 202.0,
#   'new_tests_smoothed_per_thousand': 2.611,
#   'positive_rate': 0.064,
#   'tests_per_case': 15.5,
#   'tests_units': 'people tested',
#   'total_vaccinations': None,
#   'people_vaccinated': None,
#   'people_fully_vaccinated': None,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': None,
#   'total_vaccinations_per_hundred': None,
#   'people_vaccinated_per_hundred': None,
#   'people_fully_vaccinated_per_hundred': None,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': None,
#   'stringency_index': 40.74,
#   'population': 77354.0,
#   'population_density': 163.755,
#   'median_age': None,
#   'aged_65_older': None,
#   'aged_70_older': None,
#   'gdp_per_capita': None,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 109.135,
#   'diabetes_prevalence': 7.97,
#   'female_smokers': 29.0,
#   'male_smokers': 37.8,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': None,
#   'life_expectancy': 83.73,
#   'human_development_index': 0.868,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'AGO': {'continent': 'Africa',
#   'location': 'Angola',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 64612.0,
#   'new_cases': 29.0,
#   'new_cases_smoothed': 44.429,
#   'total_deaths': 1719.0,
#   'new_deaths': 1.0,
#   'new_deaths_smoothed': 1.714,
#   'total_cases_per_million': 1904.071,
#   'new_cases_per_million': 0.855,
#   'new_cases_smoothed_per_million': 1.309,
#   'total_deaths_per_million': 50.658,
#   'new_deaths_per_million': 0.029,
#   'new_deaths_smoothed_per_million': 0.051,
#   'reproduction_rate': 0.61,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 6647925.0,
#   'people_vaccinated': 4846094.0,
#   'people_fully_vaccinated': 1801831.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 69101.0,
#   'total_vaccinations_per_hundred': 19.59,
#   'people_vaccinated_per_hundred': 14.28,
#   'people_fully_vaccinated_per_hundred': 5.31,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 2036.0,
#   'stringency_index': 63.89,
#   'population': 33933611.0,
#   'population_density': 23.89,
#   'median_age': 16.8,
#   'aged_65_older': 2.405,
#   'aged_70_older': 1.362,
#   'gdp_per_capita': 5819.495,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 276.045,
#   'diabetes_prevalence': 3.94,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': 26.664,
#   'hospital_beds_per_thousand': None,
#   'life_expectancy': 61.15,
#   'human_development_index': 0.581,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'AIA': {'continent': 'North America',
#   'location': 'Anguilla',
#   'last_updated_date': '2021-11-05',
#   'total_cases': None,
#   'new_cases': None,
#   'new_cases_smoothed': None,
#   'total_deaths': None,
#   'new_deaths': None,
#   'new_deaths_smoothed': None,
#   'total_cases_per_million': None,
#   'new_cases_per_million': None,
#   'new_cases_smoothed_per_million': None,
#   'total_deaths_per_million': None,
#   'new_deaths_per_million': None,
#   'new_deaths_smoothed_per_million': None,
#   'reproduction_rate': None,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 18706.0,
#   'people_vaccinated': 9548.0,
#   'people_fully_vaccinated': 9158.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 0.0,
#   'total_vaccinations_per_hundred': 123.68,
#   'people_vaccinated_per_hundred': 63.13,
#   'people_fully_vaccinated_per_hundred': 60.55,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 0.0,
#   'stringency_index': None,
#   'population': 15125.0,
#   'population_density': None,
#   'median_age': None,
#   'aged_65_older': None,
#   'aged_70_older': None,
#   'gdp_per_capita': None,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': None,
#   'diabetes_prevalence': None,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': None,
#   'life_expectancy': 81.88,
#   'human_development_index': None,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'ATG': {'continent': 'North America',
#   'location': 'Antigua and Barbuda',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 4078.0,
#   'new_cases': 6.0,
#   'new_cases_smoothed': 5.429,
#   'total_deaths': 104.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 0.286,
#   'total_cases_per_million': 41305.405,
#   'new_cases_per_million': 60.773,
#   'new_cases_smoothed_per_million': 54.985,
#   'total_deaths_per_million': 1053.399,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 2.894,
#   'reproduction_rate': 0.63,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 106387.0,
#   'people_vaccinated': 56269.0,
#   'people_fully_vaccinated': 50118.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 270.0,
#   'total_vaccinations_per_hundred': 107.76,
#   'people_vaccinated_per_hundred': 56.99,
#   'people_fully_vaccinated_per_hundred': 50.76,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 2735.0,
#   'stringency_index': None,
#   'population': 98728.0,
#   'population_density': 231.845,
#   'median_age': 32.1,
#   'aged_65_older': 6.933,
#   'aged_70_older': 4.631,
#   'gdp_per_capita': 21490.943,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 191.511,
#   'diabetes_prevalence': 13.17,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 3.8,
#   'life_expectancy': 77.02,
#   'human_development_index': 0.778,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'ARG': {'continent': 'South America',
#   'location': 'Argentina',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 5295260.0,
#   'new_cases': 1271.0,
#   'new_cases_smoothed': 1116.143,
#   'total_deaths': 116083.0,
#   'new_deaths': 28.0,
#   'new_deaths_smoothed': 21.143,
#   'total_cases_per_million': 116109.296,
#   'new_cases_per_million': 27.869,
#   'new_cases_smoothed_per_million': 24.474,
#   'total_deaths_per_million': 2545.355,
#   'new_deaths_per_million': 0.614,
#   'new_deaths_smoothed_per_million': 0.464,
#   'reproduction_rate': 1.01,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 27642.0,
#   'total_tests': 25134691.0,
#   'total_tests_per_thousand': 551.129,
#   'new_tests_per_thousand': 0.606,
#   'new_tests_smoothed': 40027.0,
#   'new_tests_smoothed_per_thousand': 0.878,
#   'positive_rate': 0.028,
#   'tests_per_case': 35.7,
#   'tests_units': 'tests performed',
#   'total_vaccinations': 61040687.0,
#   'people_vaccinated': 34791128.0,
#   'people_fully_vaccinated': 26363475.0,
#   'total_boosters': None,
#   'new_vaccinations': 552352.0,
#   'new_vaccinations_smoothed': 259868.0,
#   'total_vaccinations_per_hundred': 133.84,
#   'people_vaccinated_per_hundred': 76.29,
#   'people_fully_vaccinated_per_hundred': 57.81,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 5698.0,
#   'stringency_index': 42.59,
#   'population': 45605823.0,
#   'population_density': 16.177,
#   'median_age': 31.9,
#   'aged_65_older': 11.198,
#   'aged_70_older': 7.441,
#   'gdp_per_capita': 18933.907,
#   'extreme_poverty': 0.6,
#   'cardiovasc_death_rate': 191.032,
#   'diabetes_prevalence': 5.5,
#   'female_smokers': 16.2,
#   'male_smokers': 27.7,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 5.0,
#   'life_expectancy': 76.67,
#   'human_development_index': 0.845,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'ARM': {'continent': 'Asia',
#   'location': 'Armenia',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 316839.0,
#   'new_cases': 1835.0,
#   'new_cases_smoothed': 1756.143,
#   'total_deaths': 6582.0,
#   'new_deaths': 50.0,
#   'new_deaths_smoothed': 50.0,
#   'total_cases_per_million': 106747.081,
#   'new_cases_per_million': 618.235,
#   'new_cases_smoothed_per_million': 591.667,
#   'total_deaths_per_million': 2217.559,
#   'new_deaths_per_million': 16.846,
#   'new_deaths_smoothed_per_million': 16.846,
#   'reproduction_rate': 1.04,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 10281.0,
#   'total_tests': 2145909.0,
#   'total_tests_per_thousand': 722.984,
#   'new_tests_per_thousand': 3.464,
#   'new_tests_smoothed': 13969.0,
#   'new_tests_smoothed_per_thousand': 4.706,
#   'positive_rate': 0.128,
#   'tests_per_case': 7.8,
#   'tests_units': 'tests performed',
#   'total_vaccinations': 677032.0,
#   'people_vaccinated': 466785.0,
#   'people_fully_vaccinated': 210247.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 8048.0,
#   'total_vaccinations_per_hundred': 22.81,
#   'people_vaccinated_per_hundred': 15.73,
#   'people_fully_vaccinated_per_hundred': 7.08,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 2711.0,
#   'stringency_index': None,
#   'population': 2968128.0,
#   'population_density': 102.931,
#   'median_age': 35.7,
#   'aged_65_older': 11.232,
#   'aged_70_older': 7.571,
#   'gdp_per_capita': 8787.58,
#   'extreme_poverty': 1.8,
#   'cardiovasc_death_rate': 341.01,
#   'diabetes_prevalence': 7.11,
#   'female_smokers': 1.5,
#   'male_smokers': 52.1,
#   'handwashing_facilities': 94.043,
#   'hospital_beds_per_thousand': 4.2,
#   'life_expectancy': 75.09,
#   'human_development_index': 0.776,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'ABW': {'continent': 'North America',
#   'location': 'Aruba',
#   'last_updated_date': '2021-11-05',
#   'total_cases': None,
#   'new_cases': None,
#   'new_cases_smoothed': None,
#   'total_deaths': None,
#   'new_deaths': None,
#   'new_deaths_smoothed': None,
#   'total_cases_per_million': None,
#   'new_cases_per_million': None,
#   'new_cases_smoothed_per_million': None,
#   'total_deaths_per_million': None,
#   'new_deaths_per_million': None,
#   'new_deaths_smoothed_per_million': None,
#   'reproduction_rate': None,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 160012.0,
#   'people_vaccinated': 82934.0,
#   'people_fully_vaccinated': 77078.0,
#   'total_boosters': None,
#   'new_vaccinations': 233.0,
#   'new_vaccinations_smoothed': 87.0,
#   'total_vaccinations_per_hundred': 149.27,
#   'people_vaccinated_per_hundred': 77.37,
#   'people_fully_vaccinated_per_hundred': 71.9,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 812.0,
#   'stringency_index': 44.44,
#   'population': 107195.0,
#   'population_density': 584.8,
#   'median_age': 41.2,
#   'aged_65_older': 13.085,
#   'aged_70_older': 7.452,
#   'gdp_per_capita': 35973.781,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': None,
#   'diabetes_prevalence': 11.62,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': None,
#   'life_expectancy': 76.29,
#   'human_development_index': None,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'OWID_ASI': {'continent': None,
#   'location': 'Asia',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 79874513.0,
#   'new_cases': 97075.0,
#   'new_cases_smoothed': 98731.857,
#   'total_deaths': 1183429.0,
#   'new_deaths': 1519.0,
#   'new_deaths_smoothed': 1496.571,
#   'total_cases_per_million': 17072.876,
#   'new_cases_per_million': 20.749,
#   'new_cases_smoothed_per_million': 21.104,
#   'total_deaths_per_million': 252.953,
#   'new_deaths_per_million': 0.325,
#   'new_deaths_smoothed_per_million': 0.32,
#   'reproduction_rate': None,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 4882285696.0,
#   'people_vaccinated': 2683793509.0,
#   'people_fully_vaccinated': 2044266165.0,
#   'total_boosters': 25508923.0,
#   'new_vaccinations': 17697359.0,
#   'new_vaccinations_smoothed': 20719232.0,
#   'total_vaccinations_per_hundred': 104.36,
#   'people_vaccinated_per_hundred': 57.37,
#   'people_fully_vaccinated_per_hundred': 43.7,
#   'total_boosters_per_hundred': 0.55,
#   'new_vaccinations_smoothed_per_million': 4429.0,
#   'stringency_index': None,
#   'population': 4678444992.0,
#   'population_density': None,
#   'median_age': None,
#   'aged_65_older': None,
#   'aged_70_older': None,
#   'gdp_per_capita': None,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': None,
#   'diabetes_prevalence': None,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': None,
#   'life_expectancy': None,
#   'human_development_index': None,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'AUS': {'continent': 'Oceania',
#   'location': 'Australia',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 178927.0,
#   'new_cases': 1534.0,
#   'new_cases_smoothed': 1364.0,
#   'total_deaths': 1805.0,
#   'new_deaths': 10.0,
#   'new_deaths_smoothed': 11.857,
#   'total_cases_per_million': 6938.324,
#   'new_cases_per_million': 59.485,
#   'new_cases_smoothed_per_million': 52.892,
#   'total_deaths_per_million': 69.993,
#   'new_deaths_per_million': 0.388,
#   'new_deaths_smoothed_per_million': 0.46,
#   'reproduction_rate': 0.79,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 160466.0,
#   'total_tests': 43996749.0,
#   'total_tests_per_thousand': 1706.08,
#   'new_tests_per_thousand': 6.222,
#   'new_tests_smoothed': 155872.0,
#   'new_tests_smoothed_per_thousand': 6.044,
#   'positive_rate': 0.009,
#   'tests_per_case': 113.6,
#   'tests_units': 'tests performed',
#   'total_vaccinations': 36576108.0,
#   'people_vaccinated': 19261941.0,
#   'people_fully_vaccinated': 17164167.0,
#   'total_boosters': 150000.0,
#   'new_vaccinations': 197031.0,
#   'new_vaccinations_smoothed': 171755.0,
#   'total_vaccinations_per_hundred': 141.83,
#   'people_vaccinated_per_hundred': 74.69,
#   'people_fully_vaccinated_per_hundred': 66.56,
#   'total_boosters_per_hundred': 0.58,
#   'new_vaccinations_smoothed_per_million': 6660.0,
#   'stringency_index': 51.39,
#   'population': 25788217.0,
#   'population_density': 3.202,
#   'median_age': 37.9,
#   'aged_65_older': 15.504,
#   'aged_70_older': 10.129,
#   'gdp_per_capita': 44648.71,
#   'extreme_poverty': 0.5,
#   'cardiovasc_death_rate': 107.791,
#   'diabetes_prevalence': 5.07,
#   'female_smokers': 13.0,
#   'male_smokers': 16.5,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 3.84,
#   'life_expectancy': 83.44,
#   'human_development_index': 0.944,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'AUT': {'continent': 'Europe',
#   'location': 'Austria',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 865390.0,
#   'new_cases': 9388.0,
#   'new_cases_smoothed': 6599.286,
#   'total_deaths': 11451.0,
#   'new_deaths': 32.0,
#   'new_deaths_smoothed': 16.857,
#   'total_cases_per_million': 95696.462,
#   'new_cases_per_million': 1038.143,
#   'new_cases_smoothed_per_million': 729.761,
#   'total_deaths_per_million': 1266.273,
#   'new_deaths_per_million': 3.539,
#   'new_deaths_smoothed_per_million': 1.864,
#   'reproduction_rate': 1.37,
#   'icu_patients': 293.0,
#   'icu_patients_per_million': 32.4,
#   'hosp_patients': 1181.0,
#   'hosp_patients_per_million': 130.597,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 581327.0,
#   'total_tests': 98418811.0,
#   'total_tests_per_thousand': 10883.338,
#   'new_tests_per_thousand': 64.284,
#   'new_tests_smoothed': 372630.0,
#   'new_tests_smoothed_per_thousand': 41.206,
#   'positive_rate': 0.015,
#   'tests_per_case': 68.1,
#   'tests_units': 'tests performed',
#   'total_vaccinations': 11647834.0,
#   'people_vaccinated': 5939865.0,
#   'people_fully_vaccinated': 5650222.0,
#   'total_boosters': 387221.0,
#   'new_vaccinations': 41404.0,
#   'new_vaccinations_smoothed': 25075.0,
#   'total_vaccinations_per_hundred': 128.8,
#   'people_vaccinated_per_hundred': 65.68,
#   'people_fully_vaccinated_per_hundred': 62.48,
#   'total_boosters_per_hundred': 4.28,
#   'new_vaccinations_smoothed_per_million': 2773.0,
#   'stringency_index': 57.41,
#   'population': 9043072.0,
#   'population_density': 106.749,
#   'median_age': 44.4,
#   'aged_65_older': 19.202,
#   'aged_70_older': 13.748,
#   'gdp_per_capita': 45436.686,
#   'extreme_poverty': 0.7,
#   'cardiovasc_death_rate': 145.183,
#   'diabetes_prevalence': 6.35,
#   'female_smokers': 28.4,
#   'male_smokers': 30.9,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 7.37,
#   'life_expectancy': 81.54,
#   'human_development_index': 0.922,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'AZE': {'continent': 'Asia',
#   'location': 'Azerbaijan',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 542150.0,
#   'new_cases': 2440.0,
#   'new_cases_smoothed': 2175.714,
#   'total_deaths': 7208.0,
#   'new_deaths': 26.0,
#   'new_deaths_smoothed': 26.714,
#   'total_cases_per_million': 53030.594,
#   'new_cases_per_million': 238.669,
#   'new_cases_smoothed_per_million': 212.818,
#   'total_deaths_per_million': 705.053,
#   'new_deaths_per_million': 2.543,
#   'new_deaths_smoothed_per_million': 2.613,
#   'reproduction_rate': 1.05,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 15350.0,
#   'total_tests': 5243038.0,
#   'total_tests_per_thousand': 512.85,
#   'new_tests_per_thousand': 1.501,
#   'new_tests_smoothed': 10464.0,
#   'new_tests_smoothed_per_thousand': 1.024,
#   'positive_rate': 0.204,
#   'tests_per_case': 4.9,
#   'tests_units': 'tests performed',
#   'total_vaccinations': 9708264.0,
#   'people_vaccinated': 5293969.0,
#   'people_fully_vaccinated': 4414295.0,
#   'total_boosters': None,
#   'new_vaccinations': 47133.0,
#   'new_vaccinations_smoothed': 40480.0,
#   'total_vaccinations_per_hundred': 94.96,
#   'people_vaccinated_per_hundred': 51.78,
#   'people_fully_vaccinated_per_hundred': 43.18,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 3960.0,
#   'stringency_index': None,
#   'population': 10223344.0,
#   'population_density': 119.309,
#   'median_age': 32.4,
#   'aged_65_older': 6.018,
#   'aged_70_older': 3.871,
#   'gdp_per_capita': 15847.419,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 559.812,
#   'diabetes_prevalence': 7.11,
#   'female_smokers': 0.3,
#   'male_smokers': 42.5,
#   'handwashing_facilities': 83.241,
#   'hospital_beds_per_thousand': 4.7,
#   'life_expectancy': 73.0,
#   'human_development_index': 0.756,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'BHS': {'continent': 'North America',
#   'location': 'Bahamas',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 22485.0,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 19.143,
#   'total_deaths': 657.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 2.0,
#   'total_cases_per_million': 56649.551,
#   'new_cases_per_million': 0.0,
#   'new_cases_smoothed_per_million': 48.229,
#   'total_deaths_per_million': 1655.27,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 5.039,
#   'reproduction_rate': 0.62,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 263795.0,
#   'people_vaccinated': 143726.0,
#   'people_fully_vaccinated': 128242.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 1244.0,
#   'total_vaccinations_per_hundred': 66.46,
#   'people_vaccinated_per_hundred': 36.21,
#   'people_fully_vaccinated_per_hundred': 32.31,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 3134.0,
#   'stringency_index': None,
#   'population': 396914.0,
#   'population_density': 39.497,
#   'median_age': 34.3,
#   'aged_65_older': 8.996,
#   'aged_70_older': 5.2,
#   'gdp_per_capita': 27717.847,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 235.954,
#   'diabetes_prevalence': 13.17,
#   'female_smokers': 3.1,
#   'male_smokers': 20.4,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 2.9,
#   'life_expectancy': 73.92,
#   'human_development_index': 0.814,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'BHR': {'continent': 'Asia',
#   'location': 'Bahrain',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 277011.0,
#   'new_cases': 28.0,
#   'new_cases_smoothed': 37.429,
#   'total_deaths': 1393.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 0.0,
#   'total_cases_per_million': 158446.372,
#   'new_cases_per_million': 16.016,
#   'new_cases_smoothed_per_million': 21.409,
#   'total_deaths_per_million': 796.776,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 0.0,
#   'reproduction_rate': 0.84,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 17594.0,
#   'total_tests': 6985211.0,
#   'total_tests_per_thousand': 3995.442,
#   'new_tests_per_thousand': 10.064,
#   'new_tests_smoothed': 16099.0,
#   'new_tests_smoothed_per_thousand': 9.208,
#   'positive_rate': 0.002,
#   'tests_per_case': 425.3,
#   'tests_units': 'units unclear',
#   'total_vaccinations': 2793284.0,
#   'people_vaccinated': 1180702.0,
#   'people_fully_vaccinated': 1144261.0,
#   'total_boosters': None,
#   'new_vaccinations': 3471.0,
#   'new_vaccinations_smoothed': 4236.0,
#   'total_vaccinations_per_hundred': 159.77,
#   'people_vaccinated_per_hundred': 67.53,
#   'people_fully_vaccinated_per_hundred': 65.45,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 2423.0,
#   'stringency_index': None,
#   'population': 1748295.0,
#   'population_density': 1935.907,
#   'median_age': 32.4,
#   'aged_65_older': 2.372,
#   'aged_70_older': 1.387,
#   'gdp_per_capita': 43290.705,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 151.689,
#   'diabetes_prevalence': 16.52,
#   'female_smokers': 5.8,
#   'male_smokers': 37.6,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 2.0,
#   'life_expectancy': 77.29,
#   'human_development_index': 0.852,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'BGD': {'continent': 'Asia',
#   'location': 'Bangladesh',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 1570485.0,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 189.0,
#   'total_deaths': 27887.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 4.714,
#   'total_cases_per_million': 9443.488,
#   'new_cases_per_million': 0.0,
#   'new_cases_smoothed_per_million': 1.136,
#   'total_deaths_per_million': 167.687,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 0.028,
#   'reproduction_rate': 0.75,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 73306117.0,
#   'people_vaccinated': 43100706.0,
#   'people_fully_vaccinated': 30205411.0,
#   'total_boosters': None,
#   'new_vaccinations': 594269.0,
#   'new_vaccinations_smoothed': 1087891.0,
#   'total_vaccinations_per_hundred': 44.08,
#   'people_vaccinated_per_hundred': 25.92,
#   'people_fully_vaccinated_per_hundred': 18.16,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 6542.0,
#   'stringency_index': 46.3,
#   'population': 166303494.0,
#   'population_density': 1265.036,
#   'median_age': 27.5,
#   'aged_65_older': 5.098,
#   'aged_70_older': 3.262,
#   'gdp_per_capita': 3523.984,
#   'extreme_poverty': 14.8,
#   'cardiovasc_death_rate': 298.003,
#   'diabetes_prevalence': 8.38,
#   'female_smokers': 1.0,
#   'male_smokers': 44.7,
#   'handwashing_facilities': 34.808,
#   'hospital_beds_per_thousand': 0.8,
#   'life_expectancy': 72.59,
#   'human_development_index': 0.632,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'BRB': {'continent': 'North America',
#   'location': 'Barbados',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 19516.0,
#   'new_cases': 328.0,
#   'new_cases_smoothed': 337.857,
#   'total_deaths': 170.0,
#   'new_deaths': 3.0,
#   'new_deaths_smoothed': 2.714,
#   'total_cases_per_million': 67832.664,
#   'new_cases_per_million': 1140.045,
#   'new_cases_smoothed_per_million': 1174.306,
#   'total_deaths_per_million': 590.877,
#   'new_deaths_per_million': 10.427,
#   'new_deaths_smoothed_per_million': 9.434,
#   'reproduction_rate': 1.17,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 277202.0,
#   'people_vaccinated': 149355.0,
#   'people_fully_vaccinated': 127847.0,
#   'total_boosters': None,
#   'new_vaccinations': 717.0,
#   'new_vaccinations_smoothed': 898.0,
#   'total_vaccinations_per_hundred': 96.35,
#   'people_vaccinated_per_hundred': 51.91,
#   'people_fully_vaccinated_per_hundred': 44.44,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 3121.0,
#   'stringency_index': 67.59,
#   'population': 287708.0,
#   'population_density': 664.463,
#   'median_age': 39.8,
#   'aged_65_older': 14.952,
#   'aged_70_older': 9.473,
#   'gdp_per_capita': 16978.068,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 170.05,
#   'diabetes_prevalence': 13.57,
#   'female_smokers': 1.9,
#   'male_smokers': 14.5,
#   'handwashing_facilities': 88.469,
#   'hospital_beds_per_thousand': 5.8,
#   'life_expectancy': 79.19,
#   'human_development_index': 0.814,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'BLR': {'continent': 'Europe',
#   'location': 'Belarus',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 610022.0,
#   'new_cases': 1991.0,
#   'new_cases_smoothed': 1975.857,
#   'total_deaths': 4712.0,
#   'new_deaths': 16.0,
#   'new_deaths_smoothed': 16.571,
#   'total_cases_per_million': 64601.355,
#   'new_cases_per_million': 210.847,
#   'new_cases_smoothed_per_million': 209.243,
#   'total_deaths_per_million': 499.001,
#   'new_deaths_per_million': 1.694,
#   'new_deaths_smoothed_per_million': 1.755,
#   'reproduction_rate': 0.99,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 40232.0,
#   'total_tests': 9746810.0,
#   'total_tests_per_thousand': 1032.188,
#   'new_tests_per_thousand': 4.261,
#   'new_tests_smoothed': 33001.0,
#   'new_tests_smoothed_per_thousand': 3.495,
#   'positive_rate': 0.06,
#   'tests_per_case': 16.7,
#   'tests_units': 'tests performed',
#   'total_vaccinations': 4766181.0,
#   'people_vaccinated': 2759758.0,
#   'people_fully_vaccinated': 2006423.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 42026.0,
#   'total_vaccinations_per_hundred': 50.47,
#   'people_vaccinated_per_hundred': 29.23,
#   'people_fully_vaccinated_per_hundred': 21.25,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 4451.0,
#   'stringency_index': 19.44,
#   'population': 9442867.0,
#   'population_density': 46.858,
#   'median_age': 40.3,
#   'aged_65_older': 14.799,
#   'aged_70_older': 9.788,
#   'gdp_per_capita': 17167.967,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 443.129,
#   'diabetes_prevalence': 5.18,
#   'female_smokers': 10.5,
#   'male_smokers': 46.1,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 11.0,
#   'life_expectancy': 74.79,
#   'human_development_index': 0.823,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'BEL': {'continent': 'Europe',
#   'location': 'Belgium',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 1403548.0,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 6128.286,
#   'total_deaths': 26105.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 15.857,
#   'total_cases_per_million': 120659.19,
#   'new_cases_per_million': 0.0,
#   'new_cases_smoothed_per_million': 526.832,
#   'total_deaths_per_million': 2244.176,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 1.363,
#   'reproduction_rate': 1.71,
#   'icu_patients': 276.0,
#   'icu_patients_per_million': 23.727,
#   'hosp_patients': 1511.0,
#   'hosp_patients_per_million': 129.897,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': 752.105,
#   'weekly_hosp_admissions_per_million': 64.656,
#   'new_tests': 80638.0,
#   'total_tests': 22122193.0,
#   'total_tests_per_thousand': 1901.785,
#   'new_tests_per_thousand': 6.932,
#   'new_tests_smoothed': 75365.0,
#   'new_tests_smoothed_per_thousand': 6.479,
#   'positive_rate': 0.105,
#   'tests_per_case': 9.5,
#   'tests_units': 'tests performed',
#   'total_vaccinations': 16905856.0,
#   'people_vaccinated': 8726966.0,
#   'people_fully_vaccinated': 8583492.0,
#   'total_boosters': 681618.0,
#   'new_vaccinations': 4534.0,
#   'new_vaccinations_smoothed': 5463.0,
#   'total_vaccinations_per_hundred': 145.34,
#   'people_vaccinated_per_hundred': 75.02,
#   'people_fully_vaccinated_per_hundred': 73.79,
#   'total_boosters_per_hundred': 5.86,
#   'new_vaccinations_smoothed_per_million': 470.0,
#   'stringency_index': 45.83,
#   'population': 11632334.0,
#   'population_density': 375.564,
#   'median_age': 41.8,
#   'aged_65_older': 18.571,
#   'aged_70_older': 12.849,
#   'gdp_per_capita': 42658.576,
#   'extreme_poverty': 0.2,
#   'cardiovasc_death_rate': 114.898,
#   'diabetes_prevalence': 4.29,
#   'female_smokers': 25.1,
#   'male_smokers': 31.4,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 5.64,
#   'life_expectancy': 81.63,
#   'human_development_index': 0.931,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'BLZ': {'continent': 'North America',
#   'location': 'Belize',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 27894.0,
#   'new_cases': 221.0,
#   'new_cases_smoothed': 156.571,
#   'total_deaths': 509.0,
#   'new_deaths': 4.0,
#   'new_deaths_smoothed': 2.571,
#   'total_cases_per_million': 68888.532,
#   'new_cases_per_million': 545.794,
#   'new_cases_smoothed_per_million': 386.677,
#   'total_deaths_per_million': 1257.054,
#   'new_deaths_per_million': 9.879,
#   'new_deaths_smoothed_per_million': 6.351,
#   'reproduction_rate': 1.1,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': 311525.0,
#   'total_tests_per_thousand': 769.359,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': 1404.0,
#   'new_tests_smoothed_per_thousand': 3.467,
#   'positive_rate': 0.129,
#   'tests_per_case': 7.8,
#   'tests_units': 'tests performed',
#   'total_vaccinations': None,
#   'people_vaccinated': None,
#   'people_fully_vaccinated': None,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': None,
#   'total_vaccinations_per_hundred': None,
#   'people_vaccinated_per_hundred': None,
#   'people_fully_vaccinated_per_hundred': None,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': None,
#   'stringency_index': 62.04,
#   'population': 404915.0,
#   'population_density': 16.426,
#   'median_age': 25.0,
#   'aged_65_older': 3.853,
#   'aged_70_older': 2.279,
#   'gdp_per_capita': 7824.362,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 176.957,
#   'diabetes_prevalence': 17.11,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': 90.083,
#   'hospital_beds_per_thousand': 1.3,
#   'life_expectancy': 74.62,
#   'human_development_index': 0.716,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'BEN': {'continent': 'Africa',
#   'location': 'Benin',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 24804.0,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 7.857,
#   'total_deaths': 161.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 0.0,
#   'total_cases_per_million': 1992.124,
#   'new_cases_per_million': 0.0,
#   'new_cases_smoothed_per_million': 0.631,
#   'total_deaths_per_million': 12.931,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 0.0,
#   'reproduction_rate': 0.61,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
# ...
#   'tests_units': None,
#   'total_vaccinations': None,
#   'people_vaccinated': None,
#   'people_fully_vaccinated': None,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': None,
#   'total_vaccinations_per_hundred': None,
#   'people_vaccinated_per_hundred': None,
#   'people_fully_vaccinated_per_hundred': None,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': None,
#   'stringency_index': None,
#   'population': 812.0,
#   'population_density': None,
#   'median_age': None,
#   'aged_65_older': None,
#   'aged_70_older': None,
#   'gdp_per_capita': None,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': None,
#   'diabetes_prevalence': None,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': None,
#   'life_expectancy': 75.12,
#   'human_development_index': None,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'VEN': {'continent': 'South America',
#   'location': 'Venezuela',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 411574.0,
#   'new_cases': 926.0,
#   'new_cases_smoothed': 1026.714,
#   'total_deaths': 4946.0,
#   'new_deaths': 10.0,
#   'new_deaths_smoothed': 12.286,
#   'total_cases_per_million': 14338.086,
#   'new_cases_per_million': 32.259,
#   'new_cases_smoothed_per_million': 35.768,
#   'total_deaths_per_million': 172.305,
#   'new_deaths_per_million': 0.348,
#   'new_deaths_smoothed_per_million': 0.428,
#   'reproduction_rate': 0.95,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 23156914.0,
#   'people_vaccinated': 13858057.0,
#   'people_fully_vaccinated': 9271857.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 251060.0,
#   'total_vaccinations_per_hundred': 80.67,
#   'people_vaccinated_per_hundred': 48.28,
#   'people_fully_vaccinated_per_hundred': 32.3,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 8746.0,
#   'stringency_index': 86.11,
#   'population': 28704947.0,
#   'population_density': 36.253,
#   'median_age': 29.0,
#   'aged_65_older': 6.614,
#   'aged_70_older': 3.915,
#   'gdp_per_capita': 16745.022,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': 204.85,
#   'diabetes_prevalence': 6.47,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': 0.8,
#   'life_expectancy': 72.06,
#   'human_development_index': 0.711,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'VNM': {'continent': 'Asia',
#   'location': 'Vietnam',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 953547.0,
#   'new_cases': 7504.0,
#   'new_cases_smoothed': 6167.286,
#   'total_deaths': 22412.0,
#   'new_deaths': 70.0,
#   'new_deaths_smoothed': 63.714,
#   'total_cases_per_million': 9713.338,
#   'new_cases_per_million': 76.44,
#   'new_cases_smoothed_per_million': 62.823,
#   'total_deaths_per_million': 228.301,
#   'new_deaths_per_million': 0.713,
#   'new_deaths_smoothed_per_million': 0.649,
#   'reproduction_rate': 1.17,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 112591.0,
#   'total_tests': 28201175.0,
#   'total_tests_per_thousand': 287.272,
#   'new_tests_per_thousand': 1.147,
#   'new_tests_smoothed': 96319.0,
#   'new_tests_smoothed_per_thousand': 0.981,
#   'positive_rate': 0.058,
#   'tests_per_case': 17.3,
#   'tests_units': 'samples tested',
#   'total_vaccinations': 86319808.0,
#   'people_vaccinated': 59355699.0,
#   'people_fully_vaccinated': 26964109.0,
#   'total_boosters': None,
#   'new_vaccinations': 1435734.0,
#   'new_vaccinations_smoothed': 1054201.0,
#   'total_vaccinations_per_hundred': 87.93,
#   'people_vaccinated_per_hundred': 60.46,
#   'people_fully_vaccinated_per_hundred': 27.47,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 10739.0,
#   'stringency_index': 68.98,
#   'population': 98168829.0,
#   'population_density': 308.127,
#   'median_age': 32.6,
#   'aged_65_older': 7.15,
#   'aged_70_older': 4.718,
#   'gdp_per_capita': 6171.884,
#   'extreme_poverty': 2.0,
#   'cardiovasc_death_rate': 245.465,
#   'diabetes_prevalence': 6.0,
#   'female_smokers': 1.0,
#   'male_smokers': 45.9,
#   'handwashing_facilities': 85.847,
#   'hospital_beds_per_thousand': 2.6,
#   'life_expectancy': 75.4,
#   'human_development_index': 0.704,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'WLF': {'continent': 'Oceania',
#   'location': 'Wallis and Futuna',
#   'last_updated_date': '2021-11-01',
#   'total_cases': None,
#   'new_cases': None,
#   'new_cases_smoothed': None,
#   'total_deaths': None,
#   'new_deaths': None,
#   'new_deaths_smoothed': None,
#   'total_cases_per_million': None,
#   'new_cases_per_million': None,
#   'new_cases_smoothed_per_million': None,
#   'total_deaths_per_million': None,
#   'new_deaths_per_million': None,
#   'new_deaths_smoothed_per_million': None,
#   'reproduction_rate': None,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 11577.0,
#   'people_vaccinated': 5938.0,
#   'people_fully_vaccinated': 5639.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 31.0,
#   'total_vaccinations_per_hundred': 104.35,
#   'people_vaccinated_per_hundred': 53.52,
#   'people_fully_vaccinated_per_hundred': 50.83,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 2794.0,
#   'stringency_index': None,
#   'population': 11094.0,
#   'population_density': None,
#   'median_age': None,
#   'aged_65_older': None,
#   'aged_70_older': None,
#   'gdp_per_capita': None,
#   'extreme_poverty': None,
#   'cardiovasc_death_rate': None,
#   'diabetes_prevalence': None,
#   'female_smokers': None,
#   'male_smokers': None,
#   'handwashing_facilities': None,
#   'hospital_beds_per_thousand': None,
#   'life_expectancy': 79.94,
#   'human_development_index': None,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'OWID_WRL': {'continent': None,
#   'location': 'World',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 249134481.0,
#   'new_cases': 516187.0,
#   'new_cases_smoothed': 443711.857,
#   'total_deaths': 5038372.0,
#   'new_deaths': 8837.0,
#   'new_deaths_smoothed': 6945.0,
#   'total_cases_per_million': 31636.262,
#   'new_cases_per_million': 65.548,
#   'new_cases_smoothed_per_million': 56.345,
#   'total_deaths_per_million': 639.796,
#   'new_deaths_per_million': 1.122,
#   'new_deaths_smoothed_per_million': 0.882,
#   'reproduction_rate': 1.02,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 7226733966.0,
#   'people_vaccinated': 3951949378.0,
#   'people_fully_vaccinated': 3108880373.0,
#   'total_boosters': 94816913.0,
#   'new_vaccinations': 28378348.0,
#   'new_vaccinations_smoothed': 28990661.0,
#   'total_vaccinations_per_hundred': 91.77,
#   'people_vaccinated_per_hundred': 50.18,
#   'people_fully_vaccinated_per_hundred': 39.48,
#   'total_boosters_per_hundred': 1.2,
#   'new_vaccinations_smoothed_per_million': 3681.0,
#   'stringency_index': None,
#   'population': 7874965730.0,
#   'population_density': 58.045,
#   'median_age': 30.9,
#   'aged_65_older': 8.696,
#   'aged_70_older': 5.355,
#   'gdp_per_capita': 15469.207,
#   'extreme_poverty': 10.0,
#   'cardiovasc_death_rate': 233.07,
#   'diabetes_prevalence': 8.51,
#   'female_smokers': 6.434,
#   'male_smokers': 34.635,
#   'handwashing_facilities': 60.13,
#   'hospital_beds_per_thousand': 2.705,
#   'life_expectancy': 72.58,
#   'human_development_index': 0.737,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'YEM': {'continent': 'Asia',
#   'location': 'Yemen',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 9843.0,
#   'new_cases': 12.0,
#   'new_cases_smoothed': 10.0,
#   'total_deaths': 1905.0,
#   'new_deaths': 4.0,
#   'new_deaths_smoothed': 4.0,
#   'total_cases_per_million': 322.82,
#   'new_cases_per_million': 0.394,
#   'new_cases_smoothed_per_million': 0.328,
#   'total_deaths_per_million': 62.478,
#   'new_deaths_per_million': 0.131,
#   'new_deaths_smoothed_per_million': 0.131,
#   'reproduction_rate': 0.74,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': None,
#   'total_tests': None,
#   'total_tests_per_thousand': None,
#   'new_tests_per_thousand': None,
#   'new_tests_smoothed': None,
#   'new_tests_smoothed_per_thousand': None,
#   'positive_rate': None,
#   'tests_per_case': None,
#   'tests_units': None,
#   'total_vaccinations': 547019.0,
#   'people_vaccinated': 331778.0,
#   'people_fully_vaccinated': 215241.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': 3652.0,
#   'total_vaccinations_per_hundred': 1.79,
#   'people_vaccinated_per_hundred': 1.09,
#   'people_fully_vaccinated_per_hundred': 0.71,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 120.0,
#   'stringency_index': None,
#   'population': 30490639.0,
#   'population_density': 53.508,
#   'median_age': 20.3,
#   'aged_65_older': 2.922,
#   'aged_70_older': 1.583,
#   'gdp_per_capita': 1479.147,
#   'extreme_poverty': 18.8,
#   'cardiovasc_death_rate': 495.003,
#   'diabetes_prevalence': 5.35,
#   'female_smokers': 7.6,
#   'male_smokers': 29.2,
#   'handwashing_facilities': 49.542,
#   'hospital_beds_per_thousand': 0.7,
#   'life_expectancy': 66.12,
#   'human_development_index': 0.47,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'ZMB': {'continent': 'Africa',
#   'location': 'Zambia',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 209852.0,
#   'new_cases': 37.0,
#   'new_cases_smoothed': 21.429,
#   'total_deaths': 3662.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 0.286,
#   'total_cases_per_million': 11091.158,
#   'new_cases_per_million': 1.956,
#   'new_cases_smoothed_per_million': 1.133,
#   'total_deaths_per_million': 193.545,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 0.015,
#   'reproduction_rate': 0.89,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 3958.0,
#   'total_tests': 2606571.0,
#   'total_tests_per_thousand': 137.763,
#   'new_tests_per_thousand': 0.209,
#   'new_tests_smoothed': 4004.0,
#   'new_tests_smoothed_per_thousand': 0.212,
#   'positive_rate': 0.004,
#   'tests_per_case': 250.2,
#   'tests_units': 'tests performed',
#   'total_vaccinations': None,
#   'people_vaccinated': None,
#   'people_fully_vaccinated': 538310.0,
#   'total_boosters': None,
#   'new_vaccinations': None,
#   'new_vaccinations_smoothed': None,
#   'total_vaccinations_per_hundred': None,
#   'people_vaccinated_per_hundred': None,
#   'people_fully_vaccinated_per_hundred': 2.85,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': None,
#   'stringency_index': 40.74,
#   'population': 18920657.0,
#   'population_density': 22.995,
#   'median_age': 17.7,
#   'aged_65_older': 2.48,
#   'aged_70_older': 1.542,
#   'gdp_per_capita': 3689.251,
#   'extreme_poverty': 57.5,
#   'cardiovasc_death_rate': 234.499,
#   'diabetes_prevalence': 3.94,
#   'female_smokers': 3.1,
#   'male_smokers': 24.7,
#   'handwashing_facilities': 13.938,
#   'hospital_beds_per_thousand': 2.0,
#   'life_expectancy': 63.89,
#   'human_development_index': 0.584,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None},
#  'ZWE': {'continent': 'Africa',
#   'location': 'Zimbabwe',
#   'last_updated_date': '2021-11-05',
#   'total_cases': 133112.0,
#   'new_cases': 0.0,
#   'new_cases_smoothed': 26.571,
#   'total_deaths': 4685.0,
#   'new_deaths': 0.0,
#   'new_deaths_smoothed': 1.429,
#   'total_cases_per_million': 8819.937,
#   'new_cases_per_million': 0.0,
#   'new_cases_smoothed_per_million': 1.761,
#   'total_deaths_per_million': 310.426,
#   'new_deaths_per_million': 0.0,
#   'new_deaths_smoothed_per_million': 0.095,
#   'reproduction_rate': 0.76,
#   'icu_patients': None,
#   'icu_patients_per_million': None,
#   'hosp_patients': None,
#   'hosp_patients_per_million': None,
#   'weekly_icu_admissions': None,
#   'weekly_icu_admissions_per_million': None,
#   'weekly_hosp_admissions': None,
#   'weekly_hosp_admissions_per_million': None,
#   'new_tests': 6075.0,
#   'total_tests': 1381554.0,
#   'total_tests_per_thousand': 91.541,
#   'new_tests_per_thousand': 0.403,
#   'new_tests_smoothed': 3444.0,
#   'new_tests_smoothed_per_thousand': 0.228,
#   'positive_rate': 0.013,
#   'tests_per_case': 74.6,
#   'tests_units': 'tests performed',
#   'total_vaccinations': 6017688.0,
#   'people_vaccinated': 3368530.0,
#   'people_fully_vaccinated': 2649158.0,
#   'total_boosters': None,
#   'new_vaccinations': 18598.0,
#   'new_vaccinations_smoothed': 14811.0,
#   'total_vaccinations_per_hundred': 39.87,
#   'people_vaccinated_per_hundred': 22.32,
#   'people_fully_vaccinated_per_hundred': 17.55,
#   'total_boosters_per_hundred': None,
#   'new_vaccinations_smoothed_per_million': 981.0,
#   'stringency_index': 44.44,
#   'population': 15092171.0,
#   'population_density': 42.729,
#   'median_age': 19.6,
#   'aged_65_older': 2.822,
#   'aged_70_older': 1.882,
#   'gdp_per_capita': 1899.775,
#   'extreme_poverty': 21.4,
#   'cardiovasc_death_rate': 307.846,
#   'diabetes_prevalence': 1.82,
#   'female_smokers': 1.6,
#   'male_smokers': 30.7,
#   'handwashing_facilities': 36.791,
#   'hospital_beds_per_thousand': 1.7,
#   'life_expectancy': 61.49,
#   'human_development_index': 0.571,
#   'excess_mortality_cumulative_absolute': None,
#   'excess_mortality_cumulative': None,
#   'excess_mortality': None,
#   'excess_mortality_cumulative_per_million': None}}

# %%
df1=pd.read_json("C:\PRANAV\Madrid Software\Python\data sets\examples\covid.json")
df1
# Out:
#                                                  AFG    OWID_AFR         ALB  \
# continent                                       Asia        None      Europe
# location                                 Afghanistan      Africa     Albania
# last_updated_date                         2021-11-05  2021-11-05  2021-11-05
# total_cases                                 156392.0   8526645.0    187994.0
# new_cases                                       29.0      9597.0       631.0
# ...                                              ...         ...         ...
# human_development_index                        0.511        None       0.795
# excess_mortality_cumulative_absolute            None        None        None
# excess_mortality_cumulative                     None        None        None
# excess_mortality                                None        None        None
# excess_mortality_cumulative_per_million         None        None        None
#
#                                                 DZA         AND         AGO  \
# continent                                    Africa      Europe      Africa
# location                                    Algeria     Andorra      Angola
# last_updated_date                        2021-11-05  2021-11-05  2021-11-05
# total_cases                                206995.0     15618.0     64612.0
# new_cases                                     117.0         0.0        29.0
# ...                                             ...         ...         ...
# human_development_index                       0.748       0.868       0.581
# excess_mortality_cumulative_absolute           None        None        None
# excess_mortality_cumulative                    None        None        None
# excess_mortality                               None        None        None
# excess_mortality_cumulative_per_million        None        None        None
#
#                                                    AIA                  ATG  \
# continent                                North America        North America
# location                                      Anguilla  Antigua and Barbuda
# last_updated_date                           2021-11-05           2021-11-05
# total_cases                                       None               4078.0
# new_cases                                         None                  6.0
# ...                                                ...                  ...
# human_development_index                           None                0.778
# excess_mortality_cumulative_absolute              None                 None
# excess_mortality_cumulative                       None                 None
# excess_mortality                                  None                 None
# excess_mortality_cumulative_per_million           None                 None
#
#                                                    ARG         ARM  ...  \
# continent                                South America        Asia  ...
# location                                     Argentina     Armenia  ...
# last_updated_date                           2021-11-05  2021-11-05  ...
# total_cases                                  5295260.0    316839.0  ...
# new_cases                                       1271.0      1835.0  ...
# ...                                                ...         ...  ...
# human_development_index                          0.845       0.776  ...
# excess_mortality_cumulative_absolute              None        None  ...
# excess_mortality_cumulative                       None        None  ...
# excess_mortality                                  None        None  ...
# excess_mortality_cumulative_per_million           None        None  ...
#
#                                                 UZB         VUT         VAT  \
# continent                                      Asia     Oceania      Europe
# location                                 Uzbekistan     Vanuatu     Vatican
# last_updated_date                        2021-11-05  2021-11-05  2021-11-05
# total_cases                                187381.0         6.0        27.0
# new_cases                                     296.0         0.0         0.0
# ...                                             ...         ...         ...
# human_development_index                        0.72       0.609        None
# excess_mortality_cumulative_absolute           None        None        None
# excess_mortality_cumulative                    None        None        None
# excess_mortality                               None        None        None
# excess_mortality_cumulative_per_million        None        None        None
#
#                                                    VEN         VNM  \
# continent                                South America        Asia
# location                                     Venezuela     Vietnam
# last_updated_date                           2021-11-05  2021-11-05
# total_cases                                   411574.0    953547.0
# new_cases                                        926.0      7504.0
# ...                                                ...         ...
# human_development_index                          0.711       0.704
# excess_mortality_cumulative_absolute              None        None
# excess_mortality_cumulative                       None        None
# excess_mortality                                  None        None
# excess_mortality_cumulative_per_million           None        None
#
#                                                        WLF     OWID_WRL  \
# continent                                          Oceania         None
# location                                 Wallis and Futuna        World
# last_updated_date                               2021-11-01   2021-11-05
# total_cases                                           None  249134481.0
# new_cases                                             None     516187.0
# ...                                                    ...          ...
# human_development_index                               None        0.737
# excess_mortality_cumulative_absolute                  None         None
# excess_mortality_cumulative                           None         None
# excess_mortality                                      None         None
# excess_mortality_cumulative_per_million               None         None
#
#                                                 YEM         ZMB         ZWE
# continent                                      Asia      Africa      Africa
# location                                      Yemen      Zambia    Zimbabwe
# last_updated_date                        2021-11-05  2021-11-05  2021-11-05
# total_cases                                  9843.0    209852.0    133112.0
# new_cases                                      12.0        37.0         0.0
# ...                                             ...         ...         ...
# human_development_index                        0.47       0.584       0.571
# excess_mortality_cumulative_absolute           None        None        None
# excess_mortality_cumulative                    None        None        None
# excess_mortality                               None        None        None
# excess_mortality_cumulative_per_million        None        None        None
#
# [64 rows x 225 columns]

# %%
df1=pd.read_json("C:\PRANAV\Madrid Software\Python\data sets\examples\covid.json")
df1.T
# Out:
#          continent           location last_updated_date  total_cases  \
# AFG           Asia        Afghanistan        2021-11-05     156392.0
# OWID_AFR      None             Africa        2021-11-05    8526645.0
# ALB         Europe            Albania        2021-11-05     187994.0
# DZA         Africa            Algeria        2021-11-05     206995.0
# AND         Europe            Andorra        2021-11-05      15618.0
# ...            ...                ...               ...          ...
# WLF        Oceania  Wallis and Futuna        2021-11-01         None
# OWID_WRL      None              World        2021-11-05  249134481.0
# YEM           Asia              Yemen        2021-11-05       9843.0
# ZMB         Africa             Zambia        2021-11-05     209852.0
# ZWE         Africa           Zimbabwe        2021-11-05     133112.0
#
#          new_cases new_cases_smoothed total_deaths new_deaths  \
# AFG           29.0               28.0       7284.0        0.0
# OWID_AFR    9597.0           4754.429     219201.0      236.0
# ALB          631.0              522.0       2948.0        4.0
# DZA          117.0            103.571       5939.0        3.0
# AND            0.0             14.571        130.0        0.0
# ...            ...                ...          ...        ...
# WLF           None               None         None       None
# OWID_WRL  516187.0         443711.857    5038372.0     8837.0
# YEM           12.0               10.0       1905.0        4.0
# ZMB           37.0             21.429       3662.0        0.0
# ZWE            0.0             26.571       4685.0        0.0
#
#          new_deaths_smoothed total_cases_per_million  ... female_smokers  \
# AFG                    2.143                3925.953  ...           None
# OWID_AFR             173.429                 6208.03  ...           None
# ALB                    5.571                65436.24  ...            7.1
# DZA                    3.714                4639.414  ...            0.7
# AND                      0.0               201902.94  ...           29.0
# ...                      ...                     ...  ...            ...
# WLF                     None                    None  ...           None
# OWID_WRL              6945.0               31636.262  ...          6.434
# YEM                      4.0                  322.82  ...            7.6
# ZMB                    0.286               11091.158  ...            3.1
# ZWE                    1.429                8819.937  ...            1.6
#
#          male_smokers handwashing_facilities hospital_beds_per_thousand  \
# AFG              None                 37.746                        0.5
# OWID_AFR         None                   None                       None
# ALB              51.2                   None                       2.89
# DZA              30.4                 83.741                        1.9
# AND              37.8                   None                       None
# ...               ...                    ...                        ...
# WLF              None                   None                       None
# OWID_WRL       34.635                  60.13                      2.705
# YEM              29.2                 49.542                        0.7
# ZMB              24.7                 13.938                        2.0
# ZWE              30.7                 36.791                        1.7
#
#          life_expectancy human_development_index  \
# AFG                64.83                   0.511
# OWID_AFR            None                    None
# ALB                78.57                   0.795
# DZA                76.88                   0.748
# AND                83.73                   0.868
# ...                  ...                     ...
# WLF                79.94                    None
# OWID_WRL           72.58                   0.737
# YEM                66.12                    0.47
# ZMB                63.89                   0.584
# ZWE                61.49                   0.571
#
#          excess_mortality_cumulative_absolute excess_mortality_cumulative  \
# AFG                                      None                        None
# OWID_AFR                                 None                        None
# ALB                                      None                        None
# DZA                                      None                        None
# AND                                      None                        None
# ...                                       ...                         ...
# WLF                                      None                        None
# OWID_WRL                                 None                        None
# YEM                                      None                        None
# ZMB                                      None                        None
# ZWE                                      None                        None
#
#          excess_mortality excess_mortality_cumulative_per_million
# AFG                  None                                    None
# OWID_AFR             None                                    None
# ALB                  None                                    None
# DZA                  None                                    None
# AND                  None                                    None
# ...                   ...                                     ...
# WLF                  None                                    None
# OWID_WRL             None                                    None
# YEM                  None                                    None
# ZMB                  None                                    None
# ZWE                  None                                    None
#
# [225 rows x 64 columns]

# %% [markdown]
# # from sql: SKIP

# %% [markdown]
# # FROM WEBSCRAPING: SKIP

# %% [markdown]
# # writing

# %%
df=pd.read_csv("C:\\PRANAV\\Madrid Software\\Python\\data sets\\examples\\ex6.csv")
x=df[0:10]
x
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q
# 5  1.817480  0.742273  0.419395 -2.251035   Q
# 6 -0.776764  0.935518 -0.332872 -1.875641   U
# 7 -0.913135  1.530624 -0.572657  0.477252   K
# 8  0.358480 -0.497572 -0.367016  0.507702   S
# 9 -1.740877 -1.160417 -1.637830  2.172201   G

# %%
x.to_csv("data1.csv")
